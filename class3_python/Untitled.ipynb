# %%
from arcgis import GIS

# %% [markdown]
# 地図を表示する

# %%
m1 = GIS().map('Itoshima')

# %%
m1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-c5fdf41b-f8f4-40ea-b09b-8fc5c0cccebc"><img src=""></img></div>
# <div class="map-html-embed-preview-c5fdf41b-f8f4-40ea-b09b-8fc5c0cccebc"></div>

# %% [markdown]
# # 糸島市統計データの概要

# %%
# !pip install xlrd
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 KB 2.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from matplotlib import pylab as plt
import matplotlib

# %%
df=pd.read_excel(open('data/kentiku-jutaku.xls', 'rb'),
              sheet_name='木造')

# %%
df=df.set_index('heisei')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='heisei'>
# C:\Users\katsu\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\katsu\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\katsu\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20803 (\N{CJK UNIFIED IDEOGRAPH-5143}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\katsu\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
g2 = GIS("https://www.arcgis.com", "katsuyaobara", "Couri006")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\arcgis\auth\_auth\_token.py:455, in EsriBuiltInAuth.token(self)
#     454 else:
# --> 455     self._init_token_auth_handshake()
#     456     return self.token
#
# File ~\.virtualenvs\class3_python-oA6fXa-t\lib\site-packages\arcgis\auth\_auth\_token.py:355, in EsriBuiltInAuth._init_token_auth_handshake(self)
#     341 if "messages" in sign_json and (
#     342     any(
#     343         [
#    (...)
#     353     )
#     354 ):
# --> 355     raise ValueError(",".join(sign_json["messages"]))
#     356 elif signin_resp.url.lower().find("accepttermsandconditions") > -1:
#
# ValueError: Invalid username or password.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...
